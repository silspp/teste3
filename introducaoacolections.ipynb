# %% [markdown]
# <a href="https://colab.research.google.com/github/silspp/teste3/blob/main/introducaoacolections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
alunos=["fulano","sicrano"]
print (alunos)
# Out:
# ['fulano', 'sicrano']

# %%
alunos=[]
notas=[]
alunos.append("ana")
alunos.append("bruno")
alunos.append("carla")
print(alunos)
notas.append(7)
notas.append(8)
notas.append(9)
print(f"a nota de {alunos[0]} é {notas[0]}")
print(f"a nota de {alunos[1]} é {notas[1]}")
print(f"a nota de {alunos[2]} é {notas[2]}")
indice = alunos.index("ana")
media_ana = notas[indice]
print(f"\nMédia de {alunos[indice]}: {media_ana:.2f}
5. Calcule a média das notas de um aluno específico (exemplo: Ana)
aluno_escolhido = 0  # índice 0 corresponde à Ana
media = sum(notas[aluno_escolhido]) / len(notas[aluno_escolhido])
print(f"\nMédia de {alunos[aluno_escolhido]}: {media:.2f}")
# Out:
#   File "/tmp/ipython-input-2082532707.py", line 15
#     print(f"\nMédia de {alunos[indice]}: {media_ana:.2f}
#           ^
# SyntaxError: unterminated f-string literal (detected at line 15)
